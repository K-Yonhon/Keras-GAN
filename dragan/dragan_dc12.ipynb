# %% [raw]
# 100%|██████████| 10001/10001 [43:41<00:00,  3.84it/s]

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Reshape, Flatten, Activation, UpSampling2D, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.advanced_activations import ReLU, LeakyReLU, PReLU
from keras.optimizers import Adam, RMSprop
from keras.utils import multi_gpu_model

import keras
import keras.backend as K
import keras.backend.tensorflow_backend as KTF
import tensorflow as tf

from keras.layers.normalization import BatchNormalization
from keras.layers import add

import shutil, os, sys, io, random, math
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from PIL import Image
from tqdm import tqdm

os.chdir('/home/k_yonhon/py/Keras-GAN/dragan/')
sys.path.append(os.pardir)

from tensor_board_logger import TensorBoardLogger
from wasserstein_loss import WassersteinLoss, GradientPenaltyLoss, loss_func_dcgan_dis_real, loss_func_dcgan_dis_fake

config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))
session = tf.Session(config=config)
KTF.set_session(session)

# ---------------------
#  Parameter
# ---------------------
gpu_count = 1
resume = 0
dataset = np.load('../datasets/lfw32.npz')['arr_0']
# Out:
# Using TensorFlow backend.

# %%
# Residual block
def res_block_gen(model, kernal_size, filters, strides):
    
    gen = model
    
    model = Conv2D(filters = filters, kernel_size = kernal_size, strides = strides, padding = "same")(model)
    model = BatchNormalization(momentum = 0.5)(model)
    # Using Parametric ReLU
    model = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(model)
    model = Conv2D(filters = filters, kernel_size = kernal_size, strides = strides, padding = "same")(model)
    model = BatchNormalization(momentum = 0.5)(model)
        
    model = add([gen, model])
    
    return model
    
    
def up_sampling_block(model, kernal_size, filters, strides):
    
    # In place of Conv2D and UpSampling2D we can also use Conv2DTranspose (Both are used for Deconvolution)
    # Even we can have our own function for deconvolution (i.e one made in Utils.py)
    #model = Conv2DTranspose(filters = filters, kernel_size = kernal_size, strides = strides, padding = "same")(model)
    model = Conv2D(filters = filters, kernel_size = kernal_size, strides = strides, padding = "same")(model)
    model = UpSampling2D(size = 2)(model)
    model = LeakyReLU(alpha = 0.2)(model)
    
    return model


def discriminator_block(model, filters, kernel_size, strides):
    
    model = Conv2D(filters = filters, kernel_size = kernel_size, strides = strides, padding = "same")(model)
    model = BatchNormalization(momentum = 0.5)(model)
    model = LeakyReLU(alpha = 0.2)(model)
    
    return model

# %%
class DRAGAN():
    def __init__(self, dataset, gpu_count=1, resume=0):
        # ---------------------
        #  Parameter
        # ---------------------
        self.dataset = dataset
        self.gpu_count = gpu_count
        self.resume = resume
                
        self.img_rows = dataset.shape[1]
        self.img_cols = dataset.shape[2]
        self.channels = dataset.shape[3]
        self.img_shape = (self.img_rows, self.img_cols, self.channels)

        self.input_rows = 8
        self.input_cols = 8
        self.latent_dim = 128  # Noise dim
        
        self.n_critic = 5
        self.λ = 10
        optimizer = Adam(lr=0.0002, beta_1=0.5, beta_2=0.9, epsilon=None, decay=0.0, amsgrad=False)

        # ---------------------
        #  Load models
        # ---------------------
        self.critic = self.build_critic()
        self.generator = self.build_generator()
        if self.resume != 0:
            self.critic = load_model('./saved_model/dragan'+str(self.λ)+'_critic_'+str(self.resume)+'epoch.h5')
            self.generator = load_model('./saved_model/dragan'+str(self.λ)+'_gen_'+str(self.resume)+'epoch.h5')  
        
        #-------------------------------
        # Compile Critic
        #-------------------------------    
        generated_samples = Input(shape=self.img_shape) 
        critic_output_from_generated_samples = self.critic(generated_samples)
        
        real_samples = Input(shape=self.img_shape)        
        critic_output_from_real_samples = self.critic(real_samples)

        averaged_samples = Input(shape=self.img_shape)
        critic_output_from_averaged_samples = self.critic(averaged_samples)

        partial_gp_loss = partial(GradientPenaltyLoss,
                                  averaged_samples=averaged_samples,
                                  gradient_penalty_weight=self.λ)
        # Functions need names or Keras will throw an error
        partial_gp_loss.__name__ = 'gradient_penalty'

        self.critic_model = Model(inputs=[generated_samples, 
                                          real_samples,
                                          averaged_samples],
                                  outputs=[critic_output_from_generated_samples, 
                                           critic_output_from_real_samples,
                                           critic_output_from_averaged_samples])
        
        # loss_dis = loss_func_dcgan_dis_real(y_dis) + loss_func_dcgan_dis_fake(y_fake) + loss_grad
        # loss_gen = loss_func_dcgan_dis_real(y_fake)
        
        if self.gpu_count > 1:
            self.critic_model = multi_gpu_model(self.critic_model, gpus=self.gpu_count)
        self.critic_model.compile(optimizer=optimizer, 
                                  loss=[loss_func_dcgan_dis_fake, 
                                        loss_func_dcgan_dis_real, 
                                        partial_gp_loss])
        
        # print('Critic Summary:')
        # self.critic.summary()       
        
        #-------------------------------
        # Compile Generator
        #-------------------------------
        # For the generator we freeze the critic's layers
        self.critic.trainable = False
                    
        generator_input = Input(shape=(self.latent_dim,))
        generator_layers = self.generator(generator_input)
        critic_layers_for_generator = self.critic(generator_layers)
        
        self.generator_model = Model(inputs=[generator_input], 
                                     outputs=[critic_layers_for_generator])
        if self.gpu_count > 1:
            self.generator_model = multi_gpu_model(self.generator_model, gpus=self.gpu_count)
        self.generator_model.compile(optimizer=optimizer,
                                     loss=loss_func_dcgan_dis_real)        

        # print('Genarator Summary:')
        # self.generator.summary()     

    def build_generator(self):
        gen_input = Input(shape=(self.latent_dim,))
        
        model = Reshape((self.input_rows, self.input_cols, int(self.latent_dim / (self.input_rows * self.input_cols))))(gen_input)      
        model = Conv2D(filters = 64, kernel_size = 9, strides = 1, padding = "same")(model)
        model = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(model)
        
        gen_model = model
        
        # Using 16 Residual Blocks
        for index in range(16):
            model = res_block_gen(model, 3, 64, 1)
        
        model = Conv2D(filters = 64, kernel_size = 3, strides = 1, padding = "same")(model)
        model = BatchNormalization(momentum = 0.5)(model)
        model = add([gen_model, model])
        
        # Using 2 UpSampling Blocks
        for index in range(2):
            model = up_sampling_block(model, 3, 256, 1)
        
        model = Conv2D(filters = 3, kernel_size = 9, strides = 1, padding = "same")(model)
        model = Activation('tanh')(model)

        generator_model = Model(inputs = gen_input, outputs = model)
        
        print('Generator Summary:')
        generator_model.summary()
        return generator_model
    
    def build_critic(self):        
        dis_input = Input(shape = self.img_shape)
        
        model = Conv2D(filters = 64, kernel_size = 3, strides = 1, padding = "same")(dis_input)
        model = LeakyReLU(alpha = 0.2)(model)
        
        model = discriminator_block(model, 64, 3, 2)
        model = discriminator_block(model, 128, 3, 1)
        model = discriminator_block(model, 128, 3, 2)
        model = discriminator_block(model, 256, 3, 1)
        model = discriminator_block(model, 256, 3, 2)
        model = discriminator_block(model, 512, 3, 1)
        model = discriminator_block(model, 512, 3, 2)
        
        model = Flatten()(model)
        model = Dense(1024)(model)
        model = LeakyReLU(alpha = 0.2)(model)
       
        model = Dense(1)(model)
        model = Activation('sigmoid')(model) 
        
        discriminator_model = Model(inputs = dis_input, outputs = model)
        
        print('Critic Summary:')
        discriminator_model.summary()
        return discriminator_model

    def train(self, epochs, batch_size, sample_interval=5000):       
        # ---------------------
        #  for Logging
        # ---------------------
        target_dir = "./search/my_log_dir_dragan12"
        seed = 0
        image_num = 5       
        np_samples = []
        
        # Load suspended training weights
        if self.resume != 0:
            np_samples_npz = np.load('./saved_model/dragan'+str(self.λ)+'_np_'+str(self.resume)+'epoch.npz')
            for i, np_sample in enumerate(np_samples_npz):
                np_samples.append(np_sample)
        else:            
            shutil.rmtree(target_dir, ignore_errors=True)
            os.mkdir(target_dir)
                
        self.logger = TensorBoardLogger(log_dir=target_dir)            
        
        # ---------------------
        #  Training
        # ---------------------
        # Rescale the dataset -1 to 1 
        X_train = self.dataset / 127.5 - 1.0

        # Adversarial ground truths
        valid = -np.ones((batch_size, 1), dtype=np.float32)
        fake = np.ones((batch_size, 1), dtype=np.float32)
        dummy = np.zeros((batch_size, 1), dtype=np.float32)

        for epoch in tqdm(range(self.resume, self.resume + epochs + 1)):
            for _ in range(self.n_critic):
                noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
                gen_imgs = self.generator.predict(noise, batch_size=batch_size)
                
                idx = np.random.randint(0, X_train.shape[0], batch_size)
                real_imgs = X_train[idx]
                               
                # ε = np.random.uniform(size=(batch_size, 1,1,1))
                # ave_imgs = ε * real_imgs + (1-ε) * gen_imgs
                ave_imgs = real_imgs + 0.5 * np.random.random(real_imgs.shape) * real_imgs.std() 
                
                # Train Critic
                d_loss = self.critic_model.train_on_batch([gen_imgs, real_imgs, ave_imgs], 
                                                          [fake, fake, dummy])

            # Train Generator
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            g_loss = self.generator_model.train_on_batch(noise, fake)

            # ---------------------
            #  Logging
            # ---------------------
            # Backup Model
            '''
            if epoch != resume and epoch % sample_interval == 0:
                self.critic.save('./saved_model/dragan'+str(self.λ)+'_critic_'+str(epoch)+'epoch.h5')
                self.generator.save('./saved_model/dragan'+str(self.λ)+'_gen_'+str(epoch)+'epoch.h5')
                np.savez_compressed('./saved_model/dragan'+str(self.λ)+'_np_'+str(epoch)+'epoch.npz', np_samples)
            '''
            # Log Loss & Histgram
            logs = {
                "loss/Critic": d_loss[0],
                "loss/Generator": g_loss,
                "loss_Critic/D_gen": d_loss[1],
                "loss_Critic/D_real": d_loss[2],
                "loss_Critic/gradient_penalty": d_loss[3],
                "loss_Critic/total_loss": d_loss[1] + d_loss[2] + d_loss[3],                
            }

            histograms = {}
            '''
            for layer in self.critic.layers[1].layers:
                for i in range(len(layer.get_weights())):
                    if "conv" in layer.name or "dense" in layer.name:
                        name = layer.name + "/" + str(i)
                        value = layer.get_weights()[i]
                        histograms[name] = value
            '''
            self.logger.log(logs=logs, histograms=histograms, epoch=epoch)
            
            # Log generated image samples
            if epoch % sample_interval == 0:
                np.random.seed(seed)
                noise = np.random.normal(0, 1, (image_num, self.latent_dim))
                gen_imgs = self.generator.predict(noise)
                gen_imgs = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
                np_samples.append(gen_imgs)
                '''
                fig, name = self.sample_images(epoch)
                images = {epoch: fig}
                self.logger.log(images=images, epoch=epoch)
                '''
                print("%d [C loss: %f] [G loss: %f]" % (epoch, d_loss[0], g_loss))
                
        return np_samples

# %%
gan = DRAGAN(dataset, gpu_count, resume)
# Out:
# Critic Summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 6,792,001
# Trainable params: 6,788,289
# Non-trainable params: 3,712
# _________________________________________________________________
# Generator Summary:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128)          0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 8, 8, 2)      0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 64)     10432       reshape_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 8, 8, 64)     64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 64)     256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 64)     256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           p_re_lu_1[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     36928       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 64)     256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           add_1[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     36928       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 64)     0           add_2[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 64)     0           add_3[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 64)     0           add_4[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           add_5[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 64)     36928       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 64)     256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           add_6[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 64)     36928       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 64)     256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 8, 8, 64)     64          batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           add_7[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 64)     36928       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 64)     256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 64)     256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           add_8[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 64)     36928       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 64)     256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 64)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 64)     0           add_9[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     36928       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 64)     256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 64)     0           add_10[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     36928       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 64)     0           add_11[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 64)     36928       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 64)     0           add_12[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 64)     36928       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 64)     256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 64)     0           add_13[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     36928       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 64)     0           add_14[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 64)     36928       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 64)     256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 8, 8, 64)     64          batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 64)     36928       p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 64)     0           add_15[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 64)     36928       add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 64)     256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 64)     0           p_re_lu_1[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 256)    147712      add_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 16, 256)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 256)  590080      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 32, 32, 256)  0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 3)    62211       leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 3)    0           conv2d_45[0][0]
# ==================================================================================================
# Total params: 2,038,595
# Trainable params: 2,034,371
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %%
np_samples = gan.train(epochs=10000, batch_size=16, sample_interval=1000)
# Out:
#   0%|          | 0/10001 [00:00<?, ?it/s]/home/k_yonhon/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_1/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_1/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_2/cond/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_2/cond/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_4/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_4/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_5/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_5/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2322       with c_api_util.tf_buffer() as buf:
# -> 2323         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2324         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_7/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     402     try:
# --> 403       xla_compile = op.get_attr("_XlaCompile")
#     404       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326       # Convert to ValueError for backwards compatibility.
# -> 2327       raise ValueError(str(e))
#    2328     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'loss/model_1_loss_2/gradients/model_1_2/batch_normalization_7/FusedBatchNorm_grad/FusedBatchNormGrad' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self)
#    1053         try:
# -> 1054             self.this.append(this)
#    1055         except Exception:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <lambda>(self, name)
#    1039     __swig_getmethods__ = {}
# -> 1040     __getattr__ = lambda self, name: _swig_getattr(self, TF_Output, name)
#    1041     __repr__ = _swig_repr
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_getattr(self, class_type, name)
#      73 def _swig_getattr(self, class_type, name):
# ---> 74     return _swig_getattr_nondynamic(self, class_type, name, 0)
#      75
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_getattr_nondynamic(self, class_type, name, static)
#      68     if (not static):
# ---> 69         return object.__getattr__(self, name)
#      70     else:
#
# AttributeError: type object 'object' has no attribute '__getattr__'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-821c09d4c7f2> in <module>
# ----> 1 np_samples = gan.train(epochs=10000, batch_size=16, sample_interval=1000)
#
# <ipython-input-3-dffcfe953591> in train(self, epochs, batch_size, sample_interval)
#     190                 # Train Critic
#     191                 d_loss = self.critic_model.train_on_batch([gen_imgs, real_imgs, ave_imgs],
# --> 192                                                           [fake, fake, dummy])
#     193
#     194             # Train Generator
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1214         else:
#    1215             ins = x + y + sample_weights
# -> 1216         self._make_train_function()
#    1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py in _make_train_function(self)
#     507                     training_updates = self.optimizer.get_updates(
#     508                         params=self._collected_trainable_weights,
# --> 509                         loss=self.total_loss)
#     510                 updates = (self.updates +
#     511                            training_updates +
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/optimizers.py in get_updates(self, loss, params)
#     473     @interfaces.legacy_get_updates_support
#     474     def get_updates(self, loss, params):
# --> 475         grads = self.get_gradients(loss, params)
#     476         self.updates = [K.update_add(self.iterations, 1)]
#     477
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/optimizers.py in get_gradients(self, loss, params)
#      87
#      88     def get_gradients(self, loss, params):
# ---> 89         grads = K.gradients(loss, params)
#      90         if None in grads:
#      91             raise ValueError('An operation has `None` for gradient. '
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in gradients(loss, variables)
#    2755         A gradients tensor.
#    2756     """
# -> 2757     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#    2758
#    2759
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     406       xla_scope = op.get_attr("_XlaScope").decode()
#     407     except ValueError:
# --> 408       return grad_fn()  # Exit early
#     409
#     410   if not xla_compile:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     812                 # functions.
#     813                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 814                                          lambda: grad_fn(op, *out_grads))
#     815               else:
#     816                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py in _FusedBatchNormGradGrad(op, *grad)
#     938   grad_initial = [grad_grad_x, grad_grad_scale, grad_grad_offset]
#     939   grad_grad_y, grad_x, grad_scale = gradients_impl.gradients(
# --> 940       [grad_x, grad_scale, grad_offset], [grad_y, x, scale], grad_initial)
#     941   return grad_grad_y, grad_x, grad_scale, None, None
#     942
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     628   with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#     629     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 630                             gate_gradients, aggregation_method, stop_gradients)
#     631
#     632
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, src_graph)
#     696     stop_gradient_ops = [t.op for t in stop_gradients]
#     697     reachable_to_ops, pending_count, loop_state = _PendingCount(
# --> 698         to_ops, from_ops, colocate_gradients_with_ops, func_graphs, xs)
#     699
#     700     # Iterate over the collected ops.
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _PendingCount(to_ops, from_ops, colocate_gradients_with_ops, func_graphs, xs)
#     166   # Mark reachable ops from from_ops.
#     167   reached_ops = set()
# --> 168   _MarkReachedOps(from_ops, reached_ops, func_graphs)
#     169   # X in reached_ops iff X is reachable from from_ops by a path of zero or more
#     170   # backpropagatable tensors.
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MarkReachedOps(from_ops, reached_ops, func_graphs)
#     137       for output in op.outputs:
#     138         if _IsBackpropagatable(output):
# --> 139           queue.extend(_Consumers(output, func_graphs))
#     140
#     141
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _Consumers(t, func_graphs)
#     530     func_graphs.
#     531   """
# --> 532   consumers = t.consumers()
#     533   for func in func_graphs:
#     534     for input_t, placeholder in _Captures(func).items():
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in consumers(self)
#     573     """
#     574     consumer_names = c_api.TF_OperationOutputConsumers_wrapper(
# --> 575         self._as_tf_output())
#     576     # pylint: disable=protected-access
#     577     return [
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _as_tf_output(self)
#     602   def _as_tf_output(self):
#     603     # pylint: disable=protected-access
# --> 604     return c_api_util.tf_output(self.op._c_op, self.value_index)
#     605     # pylint: enable=protected-access
#     606
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/framework/c_api_util.py in tf_output(c_op, index)
#     182     Wrapped TF_Output
#     183   """
# --> 184   ret = c_api.TF_Output()
#     185   ret.oper = c_op
#     186   ret.index = index
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self)
#    1054             self.this.append(this)
#    1055         except Exception:
# -> 1056             self.this = this
#    1057     __swig_destroy__ = _pywrap_tensorflow_internal.delete_TF_Output
#    1058     __del__ = lambda self: None
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <lambda>(self, name, value)
#    1036 class TF_Output(_object):
#    1037     __swig_setmethods__ = {}
# -> 1038     __setattr__ = lambda self, name, value: _swig_setattr(self, TF_Output, name, value)
#    1039     __swig_getmethods__ = {}
#    1040     __getattr__ = lambda self, name: _swig_getattr(self, TF_Output, name)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_setattr(self, class_type, name, value)
#      57
#      58 def _swig_setattr(self, class_type, name, value):
# ---> 59     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#      60
#      61
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      41         return self.this.own(value)
#      42     if (name == "this"):
# ---> 43         if type(value).__name__ == 'SwigPyObject':
#      44             self.__dict__[name] = value
#      45             return
#
# KeyboardInterrupt:

# %% [raw]
# gan.generator.save('./saved_model/dragan'+str(gan.λ)+'_gen_'+str(10000)+'epoch.h5')
# gan.critic.save('./saved_model/dragan'+str(gan.λ)+'_critic_'+str(10000)+'epoch.h5')
# np.savez_compressed('./saved_model/dragan'+str(gan.λ)+'_np_'+str(10000)+'epoch.npz', np_samples)

# %%
import holoviews as hv
hv.notebook_extension()
for j in range(1, 11):
    y = np_samples[j]
    for i in range(5):
        if j == 1 and i == 0:
            hv_points = hv.RGB(y[i]).relabel(str(j*10000)+' epoch')
        else:
            hv_points += hv.RGB(y[i]).relabel(str(j*10000)+' epoch')
hv_points.cols(5)

# %% [raw]
# noise = np.random.normal(0, 1, (50, gan.latent_dim))
# gen_imgs = gan.generator.predict(noise)
# y = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
# for j in range(50):
#     if j == 0:
#         hv_points = hv.RGB(y[j])
#     else:
#         hv_points += hv.RGB(y[j])
# hv_points.cols(5)

# %% [raw]
# # Original
# gen_imgs = dataset / 127.5 - 1.0
# y = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
# for j in range(50):
#     if j == 0:
#         hv_points = hv.RGB(y[j])
#     else:
#         hv_points += hv.RGB(y[j])
# hv_points.cols(5)
