# %% [raw]
# 100%|██████████| 1001/1001 [1:11:33<00:00,  4.11s/it]

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Reshape, Flatten, Activation, UpSampling2D, Dense, AveragePooling2D, add, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.advanced_activations import ReLU, LeakyReLU, PReLU
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.initializers import glorot_uniform, RandomNormal
from keras.utils import multi_gpu_model

import keras
import keras.backend as K
import keras.backend.tensorflow_backend as KTF
import tensorflow as tf

import shutil, os, sys, io, random, math
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from PIL import Image
from tqdm import tqdm

os.chdir('/home/k_yonhon/py/Keras-GAN/srresgan/')
# os.chdir('\\Users\\pro18\\Documents\\py\\Keras-GAN\\wgan_gp')
sys.path.append(os.pardir)

from tensor_board_logger import TensorBoardLogger
from wasserstein_loss import WassersteinLoss, GradientPenaltyLoss, loss_func_dcgan_dis_real, loss_func_dcgan_dis_fake

config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))
session = tf.Session(config=config)
KTF.set_session(session)

# ---------------------
#  Parameter
# ---------------------
gpu_count = 1
resume = 0
dataset = np.load('../datasets/lfw128.npz')['arr_0']
# size = 128
# dataset = np.ones((1000, size, size, 3), dtype=np.float32)

# %%
def Gen_ResBlock(input_layer, filters, kernal_size=3, strides=1):
    initializer = RandomNormal(mean=0.0, stddev=0.02, seed=None)

    x = Conv2D(filters = filters, 
               kernel_size = kernal_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(input_layer)
    x = BatchNormalization(momentum = 0.9)(x)
    x = Activation("relu")(x)
    x = Conv2D(filters = filters, 
               kernel_size = kernal_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(x)
    x = BatchNormalization(momentum = 0.9)(x)
    output_layer = add([input_layer, x])
    
    return output_layer


def pixel_shuffler(input_layer):
    input_shape = K.int_shape(input_layer)
    batch_size, h, w, c = input_shape
    # batch_size is None maybe..
    rh, rw = 2, 2
    oh, ow = h * rh, w * rw
    oc = c // (rh * rw)

    x = Reshape((h, w, rh, rw, oc))(input_layer)
    # calculated = K.sqrt(model_input + 1.0) 
    # calculated = Lambda(lambda x: K.sqrt(x + 1.0), output_shape=(10,))(model_input)
    # x = K.permute_dimensions(x, (0, 1, 3, 2, 4, 5))
    x = Lambda(lambda x: K.permute_dimensions(x, (0, 1, 3, 2, 4, 5)), 
               output_shape=(h, rh, w, rw, oc))(x)
    output_layer = Reshape((oh, ow, oc))(x)
    
    return output_layer


def CBR(input_layer, filters, kernel_size=3, strides=1):
    initializer = glorot_uniform(seed=None)
    
    x = Conv2D(filters = filters, 
               kernel_size = kernel_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(input_layer)
    x = pixel_shuffler(x)
    x = BatchNormalization(momentum = 0.9)(x)
    output_layer = Activation("relu")(x)
    
    return output_layer


def Dis_ResBlock(input_layer, filters, kernal_size=3, strides=1):
    initializer = glorot_uniform(seed=None)
    
    x = Conv2D(filters = filters, 
               kernel_size = kernel_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(input_layer)
    x = LeakyReLU(alpha = 0.2)(x)
    x = Conv2D(filters = filters, 
               kernel_size = kernel_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(x)
    x = add([input_layer, x])
    output_layer = LeakyReLU(alpha = 0.2)(x)
    
    return output_layer


def SE(input_layer, r=16):
    initializer = glorot_uniform(seed=None)
    input_shape = K.int_shape(input_layer)
    batch_size, h, w, c = input_shape
    # batch_size is None maybe..
    
    x = AveragePooling2D(pool_size=(h, w), strides=None, padding='valid')(input_layer)
    x = Reshape((c,))(x)
    x = Dense(int(c/r), kernel_initializer=initializer)(x)
    x = Activation("relu")(x)
    x = Dense(c, kernel_initializer=initializer)(x)
    x = Activation("sigmoid")(x)
    # x = K.expand_dims(x, axis=2)
    # x = K.repeat_elements(x, rep=h, axis=2)
    x = Lambda(lambda x: K.expand_dims(x, axis=2),
               output_shape=(c, 1))(x)
    x = Lambda(lambda x: K.repeat_elements(x, rep=h, axis=2),
               output_shape=(c, h))(x)
    x = Lambda(lambda x: K.expand_dims(x, axis=3),
               output_shape=(c, h, 1))(x)
    x = Lambda(lambda x: K.repeat_elements(x, rep=w, axis=3),
               output_shape=(c, h, w))(x)
    output_layer = Lambda(lambda x: K.permute_dimensions(x, (0, 2, 3, 1)), 
                          output_shape=(h, w, c))(x)
    
    return output_layer
    

def Dis_SEResBlock(input_layer, filters, kernel_size=3, strides=1):
    initializer = glorot_uniform(seed=None)
    
    x = Conv2D(filters = filters, 
               kernel_size = kernel_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(input_layer)
    x = LeakyReLU(alpha = 0.2)(x)
    x = Conv2D(filters = filters, 
               kernel_size = kernel_size, strides = strides, padding = "same", 
               kernel_initializer=initializer)(x)
    x = SE(x)
    x = add([input_layer, x])
    output_layer = LeakyReLU(alpha = 0.2)(x)    
    
    return output_layer

# %%
class DRAGAN():
    def __init__(self, dataset, gpu_count=1, resume=0):
        # ---------------------
        #  Parameter
        # ---------------------
        self.dataset = dataset
        self.gpu_count = gpu_count
        self.resume = resume
                
        self.img_rows = dataset.shape[1]
        self.img_cols = dataset.shape[2]
        self.channels = dataset.shape[3]
        self.img_shape = (self.img_rows, self.img_cols, self.channels)

        self.input_rows = 8
        self.input_cols = 8
        self.latent_dim = 128  # Noise dim
        
        self.n_critic = 5
        self.λ = 10
        self.λ2 = 34
        optimizer = Adam(lr=0.0002, beta_1=0.5, beta_2=0.99, epsilon=None, decay=0.0, amsgrad=False)

        # ---------------------
        #  Load models
        # ---------------------
        self.critic = self.build_critic()
        self.generator = self.build_generator()
        if self.resume != 0:
            self.critic = load_model('./saved_model/dragan'+str(self.λ)+'_critic_'+str(self.resume)+'epoch.h5')
            self.generator = load_model('./saved_model/dragan'+str(self.λ)+'_gen_'+str(self.resume)+'epoch.h5')  
        
        #-------------------------------
        # Compile Critic
        #-------------------------------    
        generated_samples = Input(shape=self.img_shape) 
        critic_output_from_generated_samples = self.critic(generated_samples)
        
        real_samples = Input(shape=self.img_shape)        
        critic_output_from_real_samples = self.critic(real_samples)

        averaged_samples = Input(shape=self.img_shape)
        critic_output_from_averaged_samples = self.critic(averaged_samples)

        partial_gp_loss = partial(GradientPenaltyLoss,
                                  averaged_samples=averaged_samples,
                                  gradient_penalty_weight=self.λ)
        # Functions need names or Keras will throw an error
        partial_gp_loss.__name__ = 'gradient_penalty'

        self.critic_model = Model(inputs=[generated_samples, 
                                          real_samples,
                                          averaged_samples],
                                  outputs=[critic_output_from_generated_samples, 
                                           critic_output_from_real_samples,
                                           critic_output_from_averaged_samples])
        
        # loss_dis = loss_func_dcgan_dis_real(y_dis) + loss_func_dcgan_dis_fake(y_fake) + loss_grad
        # loss_gen = loss_func_dcgan_dis_real(y_fake)
        
        if self.gpu_count > 1:
            self.critic_model = multi_gpu_model(self.critic_model, gpus=self.gpu_count)
        self.critic_model.compile(optimizer=optimizer, 
                                  loss=[loss_func_dcgan_dis_fake, 
                                        loss_func_dcgan_dis_real,
                                        partial_gp_loss])

        # print('Critic Summary:')
        # self.critic.summary()       
        
        #-------------------------------
        # Compile Generator
        #-------------------------------
        # For the generator we freeze the critic's layers
        self.critic.trainable = False
                    
        generator_input = Input(shape=(self.latent_dim,))
        generator_layers = self.generator(generator_input)
        critic_layers_for_generator = self.critic(generator_layers)
        
        self.generator_model = Model(inputs=[generator_input], 
                                     outputs=[critic_layers_for_generator])
        if self.gpu_count > 1:
            self.generator_model = multi_gpu_model(self.generator_model, gpus=self.gpu_count)
        self.generator_model.compile(optimizer=optimizer,
                                     loss=loss_func_dcgan_dis_real)        

        # print('Genarator Summary:')
        # self.generator.summary()     

    def build_generator(self):
        domain = 9
        base = 64
        initializer = glorot_uniform(seed=None)

        input_layer = Input(shape=(self.latent_dim,))
        x = Dense(base*16*16, kernel_initializer=initializer)(input_layer)
        x = BatchNormalization(momentum = 0.9)(x)
        x = Activation("relu")(x)
        x1 = Reshape((16, 16, base))(x) 
        x = Gen_ResBlock(x1, base)
        x = Gen_ResBlock(x, base)
        x = Gen_ResBlock(x, base)
        x = Gen_ResBlock(x, base)
        x = Conv2D(filters = base, 
                   kernel_size = 3, strides = 1, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = BatchNormalization(momentum = 0.9)(x)
        x = add([x1, x])
        x = CBR(x, base*4)
        x = CBR(x, base*4)
        x = CBR(x, base*4)
        x = Conv2D(filters = 3, 
                   kernel_size = 9, strides = 1, padding = "same", 
                   kernel_initializer=initializer)(x)
        output_layer = Activation('tanh')(x)
        
        model = Model(inputs = input_layer, outputs = output_layer)
        print('Generator Summary:')
        model.summary()
        return model
    
    def build_critic(self):
        base = 32
        initializer = glorot_uniform(seed=None)
        input_layer = Input(shape = self.img_shape)
        input_shape = K.int_shape(input_layer)
        batch_size, h, w, c = input_shape
        
        x = Conv2D(filters = base, 
                   kernel_size = 4, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(input_layer)        
        x = LeakyReLU(alpha = 0.2)(x)
        x = Dis_SEResBlock(x,base)
        x = Dis_SEResBlock(x,base)        
        x = Conv2D(filters = base*2, 
                   kernel_size = 4, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = LeakyReLU(alpha = 0.2)(x)
        x = Dis_SEResBlock(x,base*2)
        x = Dis_SEResBlock(x,base*2)        
        x = Conv2D(filters = base*4, 
                   kernel_size = 4, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = LeakyReLU(alpha = 0.2)(x)
        x = Dis_SEResBlock(x,base*4)
        x = Dis_SEResBlock(x,base*4)        
        x = Conv2D(filters = base*8, 
                   kernel_size = 3, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = LeakyReLU(alpha = 0.2)(x)
        x = Dis_SEResBlock(x,base*8)
        x = Dis_SEResBlock(x,base*8)        
        x = Conv2D(filters = base*16, 
                   kernel_size = 3, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = LeakyReLU(alpha = 0.2)(x)
        x = Dis_SEResBlock(x,base*16)
        x = Dis_SEResBlock(x,base*16)        
        x = Conv2D(filters = base*32, 
                   kernel_size = 3, strides = 2, padding = "same", 
                   kernel_initializer=initializer)(x)        
        x = LeakyReLU(alpha = 0.2)(x)
        # output_layer = Dense(1, kernel_initializer=initializer)(x)
        x = Dense(1, kernel_initializer=initializer)(x)
        x = AveragePooling2D(pool_size=(2, 2), padding='valid')(x)
        output_layer = Flatten()(x)
        
        model = Model(inputs = input_layer, outputs = output_layer)
        print('Critic Summary:')
        model.summary()
        return model

    def train(self, epochs, batch_size, sample_interval=5000):       
        # ---------------------
        #  for Logging
        # ---------------------
        target_dir = "./search/log_srres_dragan1"
        seed = 0
        image_num = 5       
        np_samples = []
        
        # Load suspended training weights
        if self.resume != 0:
            np_samples_npz = np.load('./saved_model/dragan'+str(self.λ)+'_np_'+str(self.resume)+'epoch.npz')
            for i, np_sample in enumerate(np_samples_npz):
                np_samples.append(np_sample)
        else:            
            shutil.rmtree(target_dir, ignore_errors=True)
            os.mkdir(target_dir)
                
        self.logger = TensorBoardLogger(log_dir=target_dir)            
        
        # ---------------------
        #  Training
        # ---------------------
        # Rescale the dataset -1 to 1 
        X_train = self.dataset / 127.5 - 1.0

        # Adversarial ground truths
        minus = -np.ones((batch_size, 1), dtype=np.float32)
        plus = np.ones((batch_size, 1), dtype=np.float32)
        dummy = np.zeros((batch_size, 1), dtype=np.float32)

        for epoch in tqdm(range(self.resume, self.resume + epochs + 1)):
            for _ in range(self.n_critic):
                noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
                gen_imgs = self.generator.predict(noise, batch_size=batch_size)
                
                idx = np.random.randint(0, X_train.shape[0], batch_size)
                real_imgs = X_train[idx]
                               
                # ε = np.random.uniform(size=(batch_size, 1,1,1))
                # ave_imgs = ε * real_imgs + (1-ε) * gen_imgs
                ave_imgs = real_imgs + 0.5 * np.random.random(real_imgs.shape) * real_imgs.std() 
                
                # Train Critic
                d_loss = self.critic_model.train_on_batch([gen_imgs, real_imgs, ave_imgs], 
                                                          [plus, plus, dummy])

            # Train Generator
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            g_loss = self.generator_model.train_on_batch(noise, plus)

            # ---------------------
            #  Logging
            # ---------------------
            # Backup Model
            '''
            if epoch != resume and epoch % sample_interval == 0:
                self.critic.save('./saved_model/dragan'+str(self.λ)+'_critic_'+str(epoch)+'epoch.h5')
                self.generator.save('./saved_model/dragan'+str(self.λ)+'_gen_'+str(epoch)+'epoch.h5')
                np.savez_compressed('./saved_model/dragan'+str(self.λ)+'_np_'+str(epoch)+'epoch.npz', np_samples)
            '''
            # Log Loss & Histgram
            logs = {
                "loss/Critic": d_loss[0],
                "loss/Generator": g_loss,
                "loss_Critic/D_gen": d_loss[1],
                "loss_Critic/D_real": d_loss[2],
                "loss_Critic/gradient_penalty": d_loss[3],
                "loss_Critic/total_loss": d_loss[1] + d_loss[2] + d_loss[3],                
            }

            histograms = {}
            '''
            for layer in self.critic.layers[1].layers:
                for i in range(len(layer.get_weights())):
                    if "conv" in layer.name or "dense" in layer.name:
                        name = layer.name + "/" + str(i)
                        value = layer.get_weights()[i]
                        histograms[name] = value
            '''
            self.logger.log(logs=logs, histograms=histograms, epoch=epoch)
            
            # Log generated image samples
            if epoch % sample_interval == 0:
                np.random.seed(seed)
                noise = np.random.normal(0, 1, (image_num, self.latent_dim))
                gen_imgs = self.generator.predict(noise)
                gen_imgs = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
                np_samples.append(gen_imgs)
                '''
                fig, name = self.sample_images(epoch)
                images = {epoch: fig}
                self.logger.log(images=images, epoch=epoch)
                '''
                print("%d [C loss: %f] [G loss: %f]" % (epoch, d_loss[0], g_loss))
                
        return np_samples

# %%
gan = DRAGAN(dataset, gpu_count, resume)
# Out:
# Critic Summary:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   1568        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 32)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 32)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            66          reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           96          activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 1)        0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 64)       0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 64, 1)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 32, 64, 64)   0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 64, 64, 32)   0           lambda_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 32)   0           leaky_re_lu_1[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 32)           0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            66          reshape_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           96          activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32, 1)        0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 32, 64)       0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 32, 64, 1)    0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 32, 64, 64)   0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 64, 64, 32)   0           lambda_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           leaky_re_lu_3[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   32832       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 64)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 64)           0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            260         reshape_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 4)            0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           320         activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 64, 1)        0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 64, 32)       0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 64, 32, 1)    0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 64, 32, 32)   0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 32, 32, 64)   0           lambda_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           leaky_re_lu_6[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32, 32, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 64)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 64)           0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            260         reshape_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4)            0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           320         activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 64, 1)        0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 64, 32)       0           lambda_16[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 64, 32, 1)    0           lambda_17[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 64, 32, 32)   0           lambda_18[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 32, 32, 64)   0           lambda_19[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 64)   0           leaky_re_lu_8[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 32, 32, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  131200      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 1, 1, 128)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 128)          0           average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 8)            1032        reshape_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8)            0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          1152        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 128, 1)       0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 128, 16)      0           lambda_21[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 128, 16, 1)   0           lambda_22[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 128, 16, 16)  0           lambda_23[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 16, 16, 128)  0           lambda_24[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           leaky_re_lu_11[0][0]
#                                                                  lambda_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 16, 16, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 128)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 128)          0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            1032        reshape_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          1152        activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 128, 1)       0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 128, 16)      0           lambda_26[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 128, 16, 1)   0           lambda_27[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 128, 16, 16)  0           lambda_28[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 16, 16, 128)  0           lambda_29[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           leaky_re_lu_13[0][0]
#                                                                  lambda_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 16, 16, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 1, 1, 256)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 256)          0           average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           4112        reshape_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16)           0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          4352        activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 256, 1)       0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 256, 8)       0           lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 256, 8, 1)    0           lambda_32[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 256, 8, 8)    0           lambda_33[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 8, 8, 256)    0           lambda_34[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           leaky_re_lu_16[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 8, 8, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 256)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 256)          0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 16)           4112        reshape_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16)           0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          4352        activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 256, 1)       0           activation_16[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 256, 8)       0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 256, 8, 1)    0           lambda_37[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 256, 8, 8)    0           lambda_38[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 8, 8, 256)    0           lambda_39[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           leaky_re_lu_18[0][0]
#                                                                  lambda_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 8, 8, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    1180160     leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 4, 4, 512)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 512)    2359808     leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 4, 4, 512)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 512)    2359808     leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 1, 1, 512)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 512)          0           average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 32)           16416       reshape_9[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32)           0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 512)          16896       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 512)          0           dense_18[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 512, 1)       0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 512, 4)       0           lambda_41[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 512, 4, 1)    0           lambda_42[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 512, 4, 4)    0           lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 4, 4, 512)    0           lambda_44[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 512)    0           leaky_re_lu_21[0][0]
#                                                                  lambda_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 4, 4, 512)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 512)    2359808     leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 4, 4, 512)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 512)    2359808     leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 1, 1, 512)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 512)          0           average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 32)           16416       reshape_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32)           0           dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 512)          16896       activation_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 512)          0           dense_20[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 512, 1)       0           activation_20[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 512, 4)       0           lambda_46[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 512, 4, 1)    0           lambda_47[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 512, 4, 4)    0           lambda_48[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 4, 4, 512)    0           lambda_49[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 512)    0           leaky_re_lu_23[0][0]
#                                                                  lambda_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 4, 4, 512)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 2, 2, 1024)   4719616     leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 2, 2, 1024)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 2, 2, 1)      1025        leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 1, 1, 1)      0           dense_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1)            0           average_pooling2d_11[0][0]
# ==================================================================================================
# Total params: 19,025,565
# Trainable params: 19,025,565
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Generator Summary:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128)          0
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 16384)        2113536     input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16384)        65536       dense_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16384)        0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 16, 16, 64)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   36928       reshape_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 64)   0           reshape_11[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 64)   36928       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 64)   0           add_11[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   36928       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 64)   36928       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 64)   0           add_12[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 64)   36928       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 64)   36928       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 64)   0           add_13[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 64)   36928       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 64)   0           reshape_11[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 256)  147712      add_15[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 16, 16, 2, 2, 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 16, 2, 16, 2, 0           reshape_12[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 32, 32, 64)   0           lambda_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         reshape_13[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 256)  147712      activation_26[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 32, 32, 2, 2, 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 32, 2, 32, 2, 0           reshape_14[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 64, 64, 64)   0           lambda_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         reshape_15[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 256)  147712      activation_27[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 64, 64, 2, 2, 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 64, 2, 64, 2, 0           reshape_16[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 128, 128, 64) 0           lambda_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         reshape_17[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 128, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 3)  15555       activation_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128, 128, 3)  0           conv2d_39[0][0]
# ==================================================================================================
# Total params: 2,973,187
# Trainable params: 2,938,883
# Non-trainable params: 34,304
# __________________________________________________________________________________________________

# %%
np_samples = gan.train(epochs=1000, batch_size=64, sample_interval=100)
# Out:
#   0%|          | 0/1001 [00:00<?, ?it/s]/home/k_yonhon/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
#   0%|          | 1/1001 [00:41<11:28:50, 41.33s/it]
# 0 [C loss: 11.851939] [G loss: 1.572437]
#  10%|█         | 101/1001 [08:04<1:07:20,  4.49s/it]
# 100 [C loss: 0.314717] [G loss: 0.000060]
#  20%|██        | 201/1001 [15:22<58:09,  4.36s/it]
# 200 [C loss: 0.043430] [G loss: 0.000000]
#  30%|███       | 301/1001 [22:38<50:42,  4.35s/it]
# 300 [C loss: 4.877469] [G loss: 11.382659]
#  40%|████      | 401/1001 [29:54<43:52,  4.39s/it]
# 400 [C loss: 1.194263] [G loss: 2.380449]
#  50%|█████     | 501/1001 [37:10<36:22,  4.37s/it]
# 500 [C loss: 1.084110] [G loss: 0.034235]
#  60%|██████    | 601/1001 [44:13<27:21,  4.10s/it]
# 600 [C loss: nan] [G loss: nan]
#  70%|███████   | 701/1001 [51:03<20:28,  4.09s/it]
# 700 [C loss: nan] [G loss: nan]
#  80%|████████  | 801/1001 [57:53<13:39,  4.10s/it]
# 800 [C loss: nan] [G loss: nan]
#  90%|█████████ | 901/1001 [1:04:44<06:49,  4.10s/it]
# 900 [C loss: nan] [G loss: nan]
# 100%|██████████| 1001/1001 [1:11:33<00:00,  4.11s/it]
# 1000 [C loss: nan] [G loss: nan]

# %% [raw]
# gan.generator.save('./saved_model/dragan'+str(gan.λ)+'_gen_'+str(10000)+'epoch.h5')
# gan.critic.save('./saved_model/dragan'+str(gan.λ)+'_critic_'+str(10000)+'epoch.h5')
# np.savez_compressed('./saved_model/dragan'+str(gan.λ)+'_np_'+str(10000)+'epoch.npz', np_samples)

# %%
import holoviews as hv
hv.notebook_extension()
for j in range(1, 11):
    y = np_samples[j]
    for i in range(5):
        if j == 1 and i == 0:
            hv_points = hv.RGB(y[i]).relabel(str(j*10000)+' epoch')
        else:
            hv_points += hv.RGB(y[i]).relabel(str(j*10000)+' epoch')
hv_points.cols(5)
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# :Layout
#    .RGB.A_10000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_10000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_10000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_10000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_10000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_20000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_20000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_20000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_20000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_20000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_30000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_30000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_30000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_30000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_30000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_40000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_40000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_40000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_40000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_40000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_50000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_50000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_50000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_50000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_50000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_60000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_60000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_60000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_60000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_60000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_70000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_70000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_70000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_70000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_70000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_80000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_80000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_80000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_80000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_80000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_90000_epoch.I    :RGB   [x,y]   (R,G,B)
#    .RGB.A_90000_epoch.II   :RGB   [x,y]   (R,G,B)
#    .RGB.A_90000_epoch.III  :RGB   [x,y]   (R,G,B)
#    .RGB.A_90000_epoch.IV   :RGB   [x,y]   (R,G,B)
#    .RGB.A_90000_epoch.V    :RGB   [x,y]   (R,G,B)
#    .RGB.A_100000_epoch.I   :RGB   [x,y]   (R,G,B)
#    .RGB.A_100000_epoch.II  :RGB   [x,y]   (R,G,B)
#    .RGB.A_100000_epoch.III :RGB   [x,y]   (R,G,B)
#    .RGB.A_100000_epoch.IV  :RGB   [x,y]   (R,G,B)
#    .RGB.A_100000_epoch.V   :RGB   [x,y]   (R,G,B)

# %% [raw]
# noise = np.random.normal(0, 1, (50, gan.latent_dim))
# gen_imgs = gan.generator.predict(noise)
# y = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
# for j in range(50):
#     if j == 0:
#         hv_points = hv.RGB(y[j])
#     else:
#         hv_points += hv.RGB(y[j])
# hv_points.cols(5)

# %% [raw]
# # Original
# gen_imgs = dataset / 127.5 - 1.0
# y = ((0.5 * gen_imgs + 0.5) * 255).astype(np.uint8)
# for j in range(50):
#     if j == 0:
#         hv_points = hv.RGB(y[j])
#     else:
#         hv_points += hv.RGB(y[j])
# hv_points.cols(5)
