# %%
from keras.datasets import mnist, cifar100
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU, ReLU
from keras.layers.convolutional import (
    UpSampling2D,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    AveragePooling2D,
)
from keras.models import Sequential, Model
from keras.optimizers import Adam
import keras
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF

import shutil, os, sys, io, random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tensor_board_logger import TensorBoardLogger
from layer_visualizer import LayerVisualizer
from tqdm import tqdm

config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))
session = tf.Session(config=config)
KTF.set_session(session)

# %%
class GAN:
    def __init__(self):
        # ---------------------
        #  for log on TensorBoard
        # ---------------------
        target_dir = "./my_log_dir"
        shutil.rmtree(target_dir, ignore_errors=True)
        os.mkdir(target_dir)
        self.logger = TensorBoardLogger(log_dir=target_dir)

        # ---------------------
        #  Parameter
        # ---------------------
        self.unrolling_steps = 0
        self.multiple = 1
        self.img_rows = 32
        self.img_cols = 32
        self.channels = 3
        self.img_shape = (self.img_rows * self.multiple, self.img_cols* self.multiple, self.channels)
        self.input_rows = int(self.img_rows * self.multiple / 16)
        self.input_cols = int(self.img_cols * self.multiple / 16)
        self.latent_dim = 100  # Noiseの次元
        optimizer = Adam(0.0002, 0.5) #

        # ---------------------
        #  Build and compile the discriminator
        # ---------------------
        self.discriminator = self.build_discriminator()
        self.discriminator.trainable = True
        self.discriminator.compile(
            loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"]
        )

        # ---------------------
        #  Build and compile the combined model
        # ---------------------
        # Build the generator
        self.generator = self.build_generator()

        # Instantiate the combined model
        z = Input(shape=(self.latent_dim,))
        img = self.generator(z)
        validity = self.discriminator(img)
        self.combined = Model(z, validity)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # Compile the combined model
        self.combined.compile(
            loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"]
        )

    def build_generator(self):
        model = Sequential()
        model.add(Dense(self.input_rows * self.input_cols * 1024, activation="relu", input_dim=self.latent_dim,
                       kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None),
                       ))
        model.add(Reshape((self.input_rows, self.input_cols, 1024)))
        
        model.add(Conv2DTranspose(512, (2, 2), strides=2, padding='valid', 
                                 kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None),
                                 ))
        model.add(BatchNormalization(momentum=0.8))
        model.add(ReLU(max_value=None))
        
        model.add(Conv2DTranspose(256, (2, 2), strides=2, padding='valid', 
                                 kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None),
                                 ))
        model.add(BatchNormalization(momentum=0.8))
        model.add(ReLU(max_value=None))

        model.add(Conv2DTranspose(128, (2, 2), strides=2, padding='valid', 
                                 kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None),
                                 ))
        model.add(BatchNormalization(momentum=0.8))
        model.add(ReLU(max_value=None))
        
        model.add(Conv2DTranspose(self.channels, (2, 2), strides=2, padding='valid',
                                  kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.02, seed=None),
                                 ))                              
        model.add(Activation("tanh"))
        model.summary()
        
        noise = Input(shape=(self.latent_dim,))
        img = model(noise)
        return Model(noise, img)

    def build_discriminator(self):
        model = Sequential()
        model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=self.img_shape, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
        model.add(ZeroPadding2D(padding=((0, 1), (0, 1))))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Flatten())
        model.add(Dense(1, activation="sigmoid"))
        model.summary()
        img = Input(shape=self.img_shape)
        validity = model(img)
        return Model(img, validity)

    def train(self, epochs, batch_size=128, sample_interval=50):
        # Load the dataset
        # (X_train, _), (_, _) = mnist.load_data()
        (X_train, y_train), (_, _) = cifar100.load_data(label_mode='fine')
        X_train = X_train[y_train.flatten() == 8]     
        
        X_train = X_train.repeat(self.multiple, axis=1).repeat(self.multiple, axis=2)

        X_train = X_train / 127.5 - 1.0   # Rescale -1 to 1
        # X_train = np.expand_dims(X_train, axis=3)  # Insert a new axis.

        # Adversarial ground truths
        valid_1 = np.ones((batch_size, 1))
        fake_0 = np.zeros((batch_size, 1))
        valid = (1.2 - 0.7) * np.random.rand(batch_size, 1) + 0.7
        fake = (0.3 - 0.0) * np.random.rand(batch_size, 1) + 0.0

        for epoch in tqdm(range(epochs + 1)):

            # ---------------------
            #  Train Discriminator
            # ---------------------
            # Generate a batch of new images
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]

            # Generate a batch of new images
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            gen_imgs = self.generator.predict(noise)

            # Train the discriminator
            d_loss_real = self.discriminator.train_on_batch(
                imgs, valid
            )  # 単一バッチデータにつき一度の勾配更新を行う。
            d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # ---------------------
            #  Unrolling Process 1 (Train discriminator unrolling_step times)
            # ---------------------
            if self.unrolling_steps != 0:
                # Backup weights
                backup_weights = self.discriminator.get_weights()

                # Unrolling
                for _ in range(self.unrolling_steps):
                    # Generate a batch of new images
                    idx = np.random.randint(0, X_train.shape[0], batch_size)
                    imgs = X_train[idx]

                    # Generate a batch of new images
                    noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
                    gen_imgs = self.generator.predict(noise)

                    # Train the discriminator
                    d_loss_real = self.discriminator.train_on_batch(imgs, valid)
                    d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)

            # ---------------------
            #  Train Generator
            # ---------------------
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            g_loss = self.combined.train_on_batch(noise, valid_1)

            # ---------------------
            #  Unrolling Process 2 (Unbdo weights)
            # ---------------------
            if self.unrolling_steps != 0:
                # Undo waights
                self.discriminator.set_weights(backup_weights)

            # ---------------------
            #  Log on TensorBoard
            # ---------------------
            logs = {
                "Discriminator/loss": d_loss[0],
                "Generator/loss": g_loss[0],
                "Generator/acc": g_loss[1],
            }
            histograms = {}
            for layer in self.generator.layers[1].layers:
                for i in range(len(layer.get_weights())):
                    if "conv" in layer.name or "dense" in layer.name:
                        name = layer.name + "/" + str(i)
                        value = layer.get_weights()[i]
                        histograms[name] = value
            self.logger.log(logs=logs, histograms=histograms, epoch=epoch)

            # If at save interval => save generated image samples
            if epoch % sample_interval == 0:
                fig, name = self.sample_images(epoch)
                images = {name: fig}
                self.logger.log(images=images, epoch=epoch)
                print(
                    "%d [D loss: %f] [G loss: %f, G acc.: %.2f%%]"
                    % (epoch, d_loss[0], g_loss[0], 100 * g_loss[1])
                )

    def sample_images(self, epoch):
        r, c = 5, 5
        noise = np.random.normal(0, 1, (r * c, self.latent_dim))
        gen_imgs = self.generator.predict(noise)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5
        fig, axs = plt.subplots(r, c)
        cnt = 0
        for i in range(r):
            for j in range(c):
                axs[i, j].imshow(gen_imgs[cnt, :, :, :self.channels], cmap="gray")
                axs[i, j].axis("off")
                cnt += 1
        name = str(epoch) + ".png"
        return fig, name
        # fig.savefig("images/%d.png" % epoch)
        # plt.close()

# %%
gan = GAN()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        896
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          18496
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 9, 9, 64)          0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 9, 9, 64)          256
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 128)         512
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6401
# =================================================================
# Total params: 396,609
# Trainable params: 395,713
# Non-trainable params: 896
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4096)              413696
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 4, 4, 512)         2097664
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 8, 8, 256)         524544
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 16, 16, 128)       131200
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 32, 32, 3)         1539
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 3,172,227
# Trainable params: 3,170,435
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
gan.train(epochs=30000, batch_size=32, sample_interval=5000)
# Out:
#   0%|          | 0/30001 [00:00<?, ?it/s]/home/k_yonhon/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
#   0%|          | 1/30001 [00:17<144:37:39, 17.36s/it]
# 0 [D loss: 1.125833] [G loss: 0.905238, G acc.: 43.75%]
#  17%|█▋        | 5002/30001 [17:08<1:44:16,  4.00it/s]
# 5000 [D loss: 0.568069] [G loss: 1.232357, G acc.: 21.88%]
#  33%|███▎      | 10002/30001 [34:02<1:23:22,  4.00it/s]
# 10000 [D loss: 0.492751] [G loss: 1.489054, G acc.: 0.00%]
#  50%|█████     | 15001/30001 [50:58<1:08:34,  3.65it/s]
# 15000 [D loss: 0.483707] [G loss: 1.690753, G acc.: 0.00%]
#  67%|██████▋   | 20001/30001 [1:08:29<45:48,  3.64it/s]
# 20000 [D loss: 0.506596] [G loss: 2.189633, G acc.: 0.00%]
#  83%|████████▎ | 25002/30001 [1:25:48<24:43,  3.37it/s]
# 25000 [D loss: 0.486770] [G loss: 1.401173, G acc.: 6.25%]
# 100%|██████████| 30001/30001 [1:42:58<00:00,  3.70it/s]
# 30000 [D loss: 0.444978] [G loss: 1.971972, G acc.: 0.00%]

# %% [raw]
# gan.generator.save('./saved_model/gan_by_cnnT_generator.h5')
# gan.discriminator.save('./saved_model/gan_by_cnnT_discriminator.h5')
# gan.combined.save('./saved_model/gan_by_cnnT_combined.h5')

# %% [raw]
# from keras.models import load_model
# generator = load_model('./saved_model/gan_by_cnnT_generator.h5')

# %%
model = gan.generator.layers[1]
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 256)         524544
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 16, 16, 128)       131200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 3)         1539
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 3)         12
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 1,486,223
# Trainable params: 1,485,449
# Non-trainable params: 774
# _________________________________________________________________

# %%
for layer in model.layers:
    if "conv2d" in layer.name:
        LayerVisualizer(model, layer.name)

# %%
for layer_name in ["conv2d_5", "conv2d_6", "conv2d_7"]:
    LayerVisualizer(model, layer_name)
# Out:
# conv2d_5
# conv2d_6
# conv2d_7

# %%
(X_train, y_train), (_, _) = cifar100.load_data(label_mode='fine')
X_train = X_train[y_train.flatten() == 8]
# gen_imgs = (0.5 * X_train[0] + 0.5) * 255
gen_imgs = X_train[random.randint(0, 500)].astype('uint8')
img = Image.fromarray(gen_imgs)
img.save("images/dcgan.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FB79C357B38>
